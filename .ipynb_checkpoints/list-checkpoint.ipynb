# %%
my_list=["haseen","humaira","shazia","fozia"]
print(my_list)
print(my_list[-2])
print(my_list[-3])
print(my_list[1:4])
# Out:
# ['haseen', 'humaira', 'shazia', 'fozia']
# shazia
# humaira
# ['humaira', 'shazia', 'fozia']

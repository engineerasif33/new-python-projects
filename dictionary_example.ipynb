# %%
thisdic={
"Name":"Muhammad Asif",
"Age":" 39 year",
"qualificaiton":"MSCS"
}
print(thisdic)
x=thisdic["qualificaiton"]
print(x)
# Out:
# {'Name': 'Muhammad Asif', 'Age': ' 39 year', 'qualificaiton': 'MSCS'}
# MSCS

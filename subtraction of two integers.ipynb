# %%
n1=int(input("enter first integer:"))
n2=int(input("enter second integr:"))
res=n1-n2
print("subtraction of two integers is:",res)
# Out:
# enter first integer: 60
# enter second integr: 30
# subtraction of two integers is: 30
